# %% [markdown]
# ## 1. An article on self-driving cars dilemma's:

# %% [markdown]
# Summary:
#
# The article describes a 'game' that has been developed in which you can choose in different scenario's and dilemma's what person is going to be sacrified by self driving cars and inevitable situations. The study has been done almost accross the world and describes the different outcomes over people in different countries, to get inside on the choices they would make.

# %% [markdown]
# Interpretation:
# Based on the article, you can see that there are many different opinions and sentiments when facing the 'moral dillema's'. I wouldnt necassarily for example sacrifice someones lives only because that person crossed the path illegally. This is a senstive topic that needs further research in order to establish the right laws and regulations to ensure that as many lives as possible are saved by self-driving cars.

# %% [markdown]
# ## 2. Vision Explorer

# %%
# %matplotlib inline
from IPython.display import Image
Image('computer vision explorer.png')

# %% [markdown]
# I tried to show two persons sitting on chairs watching tv, dropdown was 'people on couch', i tried to run it three different times to see if a better outcome would be provided, but unfortunately it still didnt give a clean output. You can faintly see a chair and a blue screen which could indicate a tv, but no persons.

# %% [markdown]
# ## 3. Cat vs Dog

# %% [markdown]
# Summary:
#
#     - checked if the images are RGB levels in the range of 0-255
#     - he checked for faulty images of cats/dogs by himself on his laptop
#     - he inputed the faulty images in python to double check if they needed to be removed, which he did
#     - he stored the faulty images in two different folders, for cats & dogs
#     - he uses ImageDataGenerator to turn the images into batches of data arrays in memory
#     - he uses the flow_from_directory method of the gen object to start generating batches, which creates two numpys arrays
#     - as an extra check, he plots one picture and checks the label
#     - he then checks the labels for a couple of batches
#     - he then trains the data

# %% [markdown]
# ## BONUS

# %% [markdown]
# i did the age detection and it said 29, i am 25 :(
